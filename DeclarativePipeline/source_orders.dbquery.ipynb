-- %%
CREATE TABLE orders
(
  order_id INT,
  order_date DATE,
  order_customer_id INT,
  order_status STRING
);

-- Insert into orders
-- values (1,'2026-02-01',1,'PENDING'),
--        (2,'2026-02-01',2,'COMPLETE'),
--        (3,'2026-02-01',3,'PENDING'),
--        (4,'2026-02-01',4,'COMPLETE'),
--        (5,'2026-02-01',5,'PENDING')

-- ;
--Inserting more records.

Insert into orders
values(6,'2026-02-03',6,'COMPLETE'),
      (7,'2026-02-04',7,'PENDING');
SELECT * from orders
;
